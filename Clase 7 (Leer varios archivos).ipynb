# %%
import numpy as np
import folium 
import matplotlib.pyplot as plt
from IPython.display import display, IFrame
import os

# %%
def mi_lista_csv(varios_archivos):
    filtro = []
    for nombre in varios_archivos:
        if nombre[-4:] == '.csv':
            filtro.append(nombre)
    return filtro

# %%
def mi_mapa(archivo_mapa,ruta='./'):
    datos_mapa = np.genfromtxt(ruta+archivo_mapa,delimiter=',',dtype=float)
    t , lat_long = datos_mapa[1:,0] , datos_mapa[1:,1:3]
    mapa = folium.Map(location=lat_long[0],zoom_start=14)
    trayectoria = folium.PolyLine(locations=lat_long).add_to(mapa)
    folium.Marker(location=[lat_long[0,0],lat_long[0,1]],
                  popup="Inicio",
                  icon=folium.Icon(color='green')).add_to(mapa)
    folium.Marker(location=[lat_long[-1,0],lat_long[-1,1]],
                  popup="Final",
                  icon=folium.Icon(color='red')).add_to(mapa)
    mapa.save(ruta+archivo_mapa[:-4]+'.html')

# %%
ruta_csv = './ArchivosCSV/'
lista = os.listdir(ruta_csv)
lista = mi_lista_csv(lista)
for mapita in lista:
    mi_mapa(mapita,ruta=ruta_csv)
    mapa_html=ruta_csv+mapita[:-4]+'.html'
    print(mapa_html)
    marco = IFrame(src=mapa_html,width=250,height=250)
    display(marco)
# Out:
# ./ArchivosCSV/Ubicacin GPS - Braulio Martell Saavedra.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/Ubicacin GPS - Braulio Martell Saavedra.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ./ArchivosCSV/Raw Data - Saúl Barragán Gómez.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/Raw Data - Saúl Barragán Gómez.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ./ArchivosCSV/YoEnBici.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/YoEnBici.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ./ArchivosCSV/Trayecto_coche - Karla Verónica Lara Cruz.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/Trayecto_coche - Karla Verónica Lara Cruz.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ./ArchivosCSV/Raw Data - Andrés Ernesto Rico López.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/Raw Data - Andrés Ernesto Rico López.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ./ArchivosCSV/Raw Data - Iván Márquez Velázquez.html
#         <iframe
#             width="250"
#             height="250"
#             src="./ArchivosCSV/Raw Data - Iván Márquez Velázquez.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def dist_mapa(archivo_mapa,ruta='./'):
    datos_mapa = np.genfromtxt(ruta+archivo_mapa,delimiter=',',dtype=float)
    t = datos_mapa[1:,0]
    lat, long = datos_mapa[1:,1], datos_mapa[1:,2]
    altura = datos_mapa[1:,3]
    lat , long = np.deg2rad(lat), np.deg2rad(long)
    d_acumulada = np.zeros_like(t)
    RT = 6731e3
    x = (RT + altura)*np.cos(lat)*np.cos(long)
    y = (RT + altura)*np.cos(lat)*np.sin(long)
    z = (RT + altura)*np.sin(lat)
    for i in range(len(t)-1):
        d_acumulada[i+1] = (d_acumulada[i] 
                            + np.sqrt( (x[i+1]-x[i])**2 + 
                                     (y[i+1]-y[i])**2 + 
                                     (z[i+1]-z[i])**2 )
                           )
    return d_acumulada

# %%
for cada_mapa in lista:
    d = dist_mapa(ruta_csv+cada_mapa)
    print('archivo: ',cada_mapa)
    print('Distancia=',d[-1]/1000,' km')
# Out:
# archivo:  Ubicacin GPS - Braulio Martell Saavedra.csv
# Distancia= 2.121431469599127  km
# archivo:  Raw Data - Saúl Barragán Gómez.csv
# Distancia= 1.9404149043061132  km
# archivo:  YoEnBici.csv
# Distancia= 7.6298168699957145  km
# archivo:  Trayecto_coche - Karla Verónica Lara Cruz.csv
# Distancia= 10.106894366759631  km
# archivo:  Raw Data - Andrés Ernesto Rico López.csv
# Distancia= 11.147169413008603  km
# archivo:  Raw Data - Iván Márquez Velázquez.csv
# Distancia= nan  km
