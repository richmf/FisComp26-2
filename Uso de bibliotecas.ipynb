# %%
import numpy as np

# %%
x = np.array([2,3])
2*x
# Out:
# array([4, 6])

# %%
print(np.sin(0))
print(np.sin(np.pi))
print(np.sin(0.5*np.pi))
# Out:
# 0.0
# 1.2246467991473532e-16
# 1.0

# %%
import math as m

# %%
print(m.sin(0))
print(m.sin(m.pi))
print(m.sin(0.5*m.pi))
# Out:
# 0.0
# 1.2246467991473532e-16
# 1.0

# %%
x = np.linspace(0,np.pi,10)
print(np.sin(x))
print(m.sin(x)) #Esto no funciona
# Out:
# [0.00000000e+00 3.42020143e-01 6.42787610e-01 8.66025404e-01
#  9.84807753e-01 9.84807753e-01 8.66025404e-01 6.42787610e-01
#  3.42020143e-01 1.22464680e-16]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 x = np.linspace(0,np.pi,10)
#       2 print(np.sin(x))
# ----> 3 print(m.sin(x)) #Esto no funciona
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
print(np.sin(1e6*np.pi))
print(m.sin(1e6*m.pi))
# Out:
# -2.231912181360871e-10
# -2.231912181360871e-10

# %%
print(np.sin(1e6*np.pi%(2*np.pi)))
#print(m.sin(1e6*m.pi))
# Out:
# -1.0072678315071163e-10

# %%
print(np.sin(1e3*np.pi%(2*np.pi)))
print(np.sin(1e6*np.pi))
# Out:
# -1.9919689537265752e-13
# -2.231912181360871e-10

# %%
import mpmath as mp

# %%
mp.dps = 1e50
mp.sin(1e6*mp.pi)
# Out:
# mpf('-2.2319121813608711e-10')
