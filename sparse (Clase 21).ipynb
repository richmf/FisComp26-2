# %%
import numpy as np
import numpy.linalg as la
import scipy.sparse as sm
import scipy.sparse.linalg as sml

# %%
A = np.array([ [0,3,0],[7,0,0],[0,0,1] ])
print(np.dot(A,A))
A
# Out:
# [[21  0  0]
#  [ 0 21  0]
#  [ 0  0  1]]
# array([[0, 3, 0],
#        [7, 0, 0],
#        [0, 0, 1]])

# %%
B = sm.csc_matrix([ [0,3,0],[7,0,0],[0,0,1] ])
print(B)
B.toarray()
# Out:
#   (1, 0)	7
#   (0, 1)	3
#   (2, 2)	1
# array([[0, 3, 0],
#        [7, 0, 0],
#        [0, 0, 1]])

# %%
B = sm.csr_matrix([ [0,3,0],[7,0,0],[0,0,1] ])
print(B)
B.toarray()
# Out:
#   (0, 1)	3
#   (1, 0)	7
#   (2, 2)	1
# array([[0, 3, 0],
#        [7, 0, 0],
#        [0, 0, 1]])

# %%
print(np.dot(B,B))
# Out:
#   (0, 0)	21
#   (1, 1)	21
#   (2, 2)	1

# %%
B.toarray()
# Out:
# array([[0, 3, 0],
#        [7, 0, 0],
#        [0, 0, 1]])

# %%
B = sm.csc_matrix([ [0,3,0],[7,0,0],[0,0,1] ])
B_inv = sml.inv(B)

# %%
# %%timeit
B2_dot = np.dot(B,B)
B2_dot
# Out:
# 42.7 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
B2_arr = B@B
B2_arr
# Out:
# 35.8 µs ± 163 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
B@B_inv.toarray()
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
v = np.array([1,2,3])

# %%
np.dot(B,v)
# Out:
# array([<3x3 sparse matrix of type '<class 'numpy.int64'>'
#        	with 3 stored elements in Compressed Sparse Column format>,
#        <3x3 sparse matrix of type '<class 'numpy.int64'>'
#        	with 3 stored elements in Compressed Sparse Column format>,
#        <3x3 sparse matrix of type '<class 'numpy.int64'>'
#        	with 3 stored elements in Compressed Sparse Column format>],
#       dtype=object)

# %%
B@v
# Out:
# array([6, 7, 3])

# %%
A = np.arange(1,7)
A
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
B = A.reshape(2,3)
B
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
B_vec = B.transpose().reshape(1,6)[0]
B_vec
# Out:
# array([1, 4, 2, 5, 3, 6])

# %%
B_vec.reshape(3,2).transpose()
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
