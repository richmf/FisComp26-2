# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def integra_h2(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(1,len(x)-1):
        integral += f[i+1] + 22*f[i] + f[i-1]
    integral += 0.5*(17*f[0] + 7*f[1] + f[2] - f[3])
    integral += 0.5*(17*f[-1] + 7*f[-2] + f[-3] - f[-4])
    return integral*h/24

def int_Riem(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(len(x)-1):
        integral += f[i]
    return integral*h

def integra_h2_impar(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(1,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

def integra_h2_par(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(2,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    return integral*h/3

def integra_h2_mejorado(f,x):
    if len(x)%2 == 0:
        integral = integra_h2_par(f,x)
    else:
        integral = integra_h2_impar(f,x)
    return integral

# %%
def integra_h2_unificado(f,x):
    integral , h , N , inicio = 0 , x[1]-x[0] , len(x) , 1
    if N%2 == 0:
        inicio = 2
        integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    for i in range(inicio,N,2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

# %%
x = np.linspace(0,np.pi,50)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral h2 ',integra_h2(y,x))
print('Integral Riem ',int_Riem(y,x))
print('Integral h2 mejorado',integra_h2_mejorado(y,x))
print('Integral h2 unificado',integra_h2_unificado(y,x))
# Out:
# h =  0.0641141357875468
# Integral h2  2.0000015908803026
# Integral Riem  1.9993148493240624
# Integral h2 mejorado 2.000002983102432
# Integral h2 unificado 2.000002983102433

# %%
# %timeit integra_h2(y,x)
# Out:
# 16.4 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit int_Riem(y,x)
# Out:
# 3.67 µs ± 19.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit integra_h2_mejorado(y,x)
# Out:
# 8.79 µs ± 38.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit integra_h2_unificado(y,x)
# Out:
# 8.73 µs ± 50 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
x = np.linspace(0,np.pi,500)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral Riem ',int_Riem(y,x))
# Out:
# h =  0.006295776860901389
# Integral Riem  1.9999933938612575

# %%
# %timeit int_Riem(y,x)
# Out:
# 35 µs ± 341 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
from numba import njit

# %%
@njit
def integra_h2_unificado_numba(f,x):
    integral , h , N , inicio = 0 , x[1]-x[0] , len(x) , 1
    if N%2 == 0:
        inicio = 2
        integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    for i in range(inicio,N,2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

# %%
x = np.linspace(0,np.pi,50)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral h2 unificado',integra_h2_unificado_numba(y,x))
# Out:
# h =  0.0641141357875468
# Integral h2 unificado 2.000002983102433

# %%
# %timeit integra_h2_unificado_numba(y,x)
# Out:
# 172 ns ± 0.964 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
